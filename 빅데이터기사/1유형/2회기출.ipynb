# %% [markdown]
# ## 문제 1.
# - 다음은 Boston Housing 데이터 세트이다. 범죄율 컬럼인 CRIM 항옥의 상위에서 10번째 값(즉, 범죄율을 큰 순서로 내림차순 정렬했을 때 10번째 위치한 값)으로 상위 10개의 값을 변환한 후, age가 80 이상인 데이터를 추출하여 crim의 평균값을 계산하시오.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\spa84\\빅데이터분석기사_실기_최종본\\작업장_제1유형'

# %%
import pandas as pd 
import numpy as np

df = pd.read_csv("data/2회/201_boston.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ### 풀이1

# %%
df2 = df.sort_values('CRIM', ascending=False).reset_index(drop=True)
df2
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0    88.97620   0.0  18.10   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 1    73.53410   0.0  18.10   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
# 2    67.92080   0.0  18.10   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 3    51.13580   0.0  18.10   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 4    45.74610   0.0  18.10   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 501   0.01311  90.0   1.22   0.0  0.403  7.249   21.9  8.6966   5.0  226.0
# 502   0.01301  35.0   1.52   0.0  0.442  7.241   49.3  7.0379   1.0  284.0
# 503   0.01096  55.0   2.25   0.0  0.389  6.453   31.9  7.3073   1.0  300.0
# 504   0.00906  90.0   2.97   0.0  0.400  7.088   20.8  7.3073   1.0  285.0
# 505   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
#
#      PTRATIO       B  LSTAT
# 0       20.2  396.90  17.21
# 1       20.2   16.45  20.62
# 2       20.2  384.97  22.98
# 3       20.2    2.60  10.11
# 4       20.2   88.27  36.98
# ..       ...     ...    ...
# 501     17.9  395.93   4.81
# 502     15.5  394.74   5.49
# 503     15.3  394.72   8.23
# 504     15.3  394.72   7.85
# 505     15.3  396.90   4.98
#
# [506 rows x 13 columns]

# %%
value_10 = df2.iloc[9, 0]
value_10
# Out:
# 25.9406

# %%
df2.iloc[0:9, 0] = value_10
df2.head(12)
# Out:
#        CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0   25.9406  0.0   18.1   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 1   25.9406  0.0   18.1   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
# 2   25.9406  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 3   25.9406  0.0   18.1   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 4   25.9406  0.0   18.1   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# 5   25.9406  0.0   18.1   0.0  0.693  5.531   85.4  1.6074  24.0  666.0
# 6   25.9406  0.0   18.1   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 7   25.9406  0.0   18.1   0.0  0.679  6.202   78.7  1.8629  24.0  666.0
# 8   25.9406  0.0   18.1   0.0  0.597  5.155  100.0  1.5894  24.0  666.0
# 9   25.9406  0.0   18.1   0.0  0.679  5.304   89.1  1.6475  24.0  666.0
# 10  25.0461  0.0   18.1   0.0  0.693  5.987  100.0  1.5888  24.0  666.0
# 11  24.8017  0.0   18.1   0.0  0.693  5.349   96.0  1.7028  24.0  666.0
#
#     PTRATIO       B  LSTAT
# 0      20.2  396.90  17.21
# 1      20.2   16.45  20.62
# 2      20.2  384.97  22.98
# 3      20.2    2.60  10.11
# 4      20.2   88.27  36.98
# 5      20.2  329.46  27.38
# 6      20.2  396.90  30.59
# 7      20.2   18.82  14.52
# 8      20.2  210.97  20.08
# 9      20.2  127.36  26.64
# 10     20.2  396.90  26.77
# 11     20.2  396.90  19.77

# %%
df2[df2['AGE']>=80]['CRIM'].mean()
# Out:
# 5.759386624999999

# %% [markdown]
# ### 풀이2

# %%
value_10 = df.nlargest(10, 'CRIM')['CRIM'].iloc[9]

# %%
top10 = df.nlargest(10, 'CRIM').index.tolist()
top10
# Out:
# [380, 418, 405, 410, 414, 404, 398, 427, 413, 417]

# %%
df.iloc[top10, 0] = value_10

# %%
df.iloc[top10]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 380  25.9406  0.0   18.1   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 418  25.9406  0.0   18.1   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
# 405  25.9406  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 410  25.9406  0.0   18.1   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 414  25.9406  0.0   18.1   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# 404  25.9406  0.0   18.1   0.0  0.693  5.531   85.4  1.6074  24.0  666.0
# 398  25.9406  0.0   18.1   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 427  25.9406  0.0   18.1   0.0  0.679  6.202   78.7  1.8629  24.0  666.0
# 413  25.9406  0.0   18.1   0.0  0.597  5.155  100.0  1.5894  24.0  666.0
# 417  25.9406  0.0   18.1   0.0  0.679  5.304   89.1  1.6475  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 380     20.2  396.90  17.21
# 418     20.2   16.45  20.62
# 405     20.2  384.97  22.98
# 410     20.2    2.60  10.11
# 414     20.2   88.27  36.98
# 404     20.2  329.46  27.38
# 398     20.2  396.90  30.59
# 427     20.2   18.82  14.52
# 413     20.2  210.97  20.08
# 417     20.2  127.36  26.64

# %%
df_80 = df[df['AGE'] >= 80]
print(df_80['CRIM'].mean())
# Out:
# 5.759386625

# %% [markdown]
# ## 문제 2.
# - 다음은 California Housing 데이터 세트이다. 주어진 데이터의 첫 번째 행부터 순서대로 80%까지의 데이터를 훈련 데이터로 추출 후, 전체 방 갯수 컬럼을 의미하는 'total_bedrooms' 변수의 결측치를 'total_bedrooms' 변수의 중앙값으로 대체하 데이터 세트를 구성한다. 결측치 대체 전의 'total_bedrooms' 변수 표준편차 값과 결측치 대체 후의 'total_bedrooms'  변수 표준편차 값의 차이에 대한 절댓값을 계산하시오.

# %%
df = pd.read_csv("data/2회/202_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
location = int(0.8 * len(df))

# %%
train = df.iloc[:location]
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.11     37.74                11.0       3886.0           599.0
# 16508    -121.10     37.80                35.0       1853.0           331.0
# 16509    -121.11     37.76                22.0       2606.0           411.0
# 16510    -121.16     37.73                 7.0       4956.0           941.0
# 16511    -121.25     37.76                22.0       2430.0           417.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 16507      1605.0       529.0         4.4213            182700.0
# 16508       958.0       340.0         3.3578            149000.0
# 16509      1252.0       397.0         4.1833            192100.0
# 16510      3006.0       915.0         3.4426            139000.0
# 16511      1292.0       391.0         3.4009            182400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 16507          INLAND
# 16508          INLAND
# 16509          INLAND
# 16510          INLAND
# 16511          INLAND
#
# [16512 rows x 10 columns]

# %%
train.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        159
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
before_std = train['total_bedrooms'].std()
before_std
# Out:
# 435.900577052527

# %%
after_std = train['total_bedrooms'].fillna(train['total_bedrooms'].median()).std()
after_std
# Out:
# 433.9254297608813

# %%
print(abs(after_std - before_std))
# Out:
# 1.975147291645726

# %% [markdown]
# ## 문제 3.
# - 2번 문항에서 활용한 California Housing 데이터 세트를 그대로 활용한다. 인구 컬럼인 population 항목의 이상값의 합계를 계산하시오.
#     + *이상값은 평균에서 1.5x표준편차를 초과하거나 미만인 값의 범위로 정한다.

# %%
import pandas as pd 
import numpy as np

df = pd.read_csv("data/2회/202_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
lower_bound = df['population'].mean() - 1.5 * df['population'].std()
upper_bound = df['population'].mean() + 1.5 * df['population'].std()

outliers = df[(df['population']>upper_bound)|(df['population']<lower_bound)]
outliers
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 95       -122.26     37.80                36.0       5329.0          2477.0
# 185      -122.23     37.79                43.0       5963.0          1344.0
# 283      -122.16     37.79                22.0      12842.0          2048.0
# 460      -122.26     37.87                52.0       1087.0           371.0
# 485      -122.26     37.86                35.0       5161.0          1744.0
# ...          ...       ...                 ...          ...             ...
# 20543    -121.74     38.55                33.0       6861.0          1820.0
# 20544    -121.76     38.55                23.0       8800.0          1857.0
# 20563    -121.75     38.67                 9.0      12139.0          2640.0
# 20604    -121.54     39.12                17.0       4251.0           899.0
# 20629    -121.39     39.12                28.0      10035.0          1856.0
#
#        population  households  median_income  median_house_value  \
# 95         3469.0      2323.0         2.0096            130000.0
# 185        4367.0      1231.0         2.1917            112800.0
# 283        4985.0      1967.0         5.9849            371000.0
# 460        3337.0       350.0         1.4012            175000.0
# 485        3276.0      1742.0         1.6307            253600.0
# ...           ...         ...            ...                 ...
# 20543      3717.0      1767.0         1.7311            182600.0
# 20544      6330.0      1832.0         2.0650            219400.0
# 20563      6837.0      2358.0         3.1250            132500.0
# 20604      3265.0       934.0         2.3496             65000.0
# 20629      6912.0      1818.0         2.0943            108300.0
#
#       ocean_proximity
# 95           NEAR BAY
# 185          NEAR BAY
# 283          NEAR BAY
# 460          NEAR BAY
# 485          NEAR BAY
# ...               ...
# 20543          INLAND
# 20544          INLAND
# 20563          INLAND
# 20604          INLAND
# 20629          INLAND
#
# [1207 rows x 10 columns]

# %%
outliers['population'].sum()
# Out:
# 5607295.0
