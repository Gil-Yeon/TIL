# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy import stats
import matplotlib.pyplot as plt
import plotly.express as px
import scipy
import seaborn as sns
import matplotlib.font_manager as fm
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
import math
import warnings
import pingouin as pg
# Out:
# Bad key text.latex.preview in file C:\Users\spa84\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file C:\Users\spa84\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file C:\Users\spa84\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 418 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file C:\Users\spa84\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 466 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file C:\Users\spa84\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 477 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file C:\Users\spa84\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 479 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
warnings.simplefilter('ignore')

# %%
font_path = "C:\\Users\\spa84\\Downloads\\text_mining\\NanumGothic.ttf"  # 나눔 폰트의 경로를 지정
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc("font", family=font_name)

# %%
df = pd.read_csv('../data/APT_data.csv')

# %%
df
# Out:
#        Floor  Building_Age   JS_BA  Population    IR    LC_index    CA_index  \
# 0        2.0            35   73.02      537081  1.75   94.700000   98.600000
# 1        6.0            19   59.94      120430  0.50  104.900000  102.300000
# 2       12.0             4   31.01      291841  0.50  103.100000  101.500000
# 3        1.0            25   57.19      421837  2.75   75.900000   82.400000
# 4        3.0             4   59.99      435952  1.25   90.400000   95.300000
# ...      ...           ...     ...         ...   ...         ...         ...
# 99995   12.0            13  114.88      122799  2.00   82.200000   87.500000
# 99996   14.0            33   62.22      332026  1.50   95.900000  100.000000
# 99997   17.0            16   84.82      291572  1.75   83.300000   88.300000
# 99998   23.0            13  116.19      662019  1.75   95.000000   98.700000
# 99999   18.0             8   31.37      484742  3.25   74.497276   81.482483
#
#          TC_index   SDT_index  Crime_Rates  ...  Sell_Price  \
# 0       96.500000   87.290715     1.372355  ...   151666.67
# 1      102.200000  119.460536     2.170927  ...   141314.29
# 2      101.100000  133.526430     0.786010  ...    29250.00
# 3       80.100000  115.191606     1.089223  ...    22050.00
# 4       91.000000  107.634598     1.057025  ...    95000.00
# ...           ...         ...          ...  ...         ...
# 99995   85.100000  115.250447     3.687960  ...    53963.64
# 99996   98.200000   92.764706     0.628667  ...    29383.33
# 99997   85.900000  122.227191     1.100749  ...    61811.11
# 99998   96.900000   69.882353     0.834577  ...   209000.00
# 99999   78.518234  102.716057     0.947923  ...    16266.67
#
#        Shortest_Distance_to_Subway  Shortest_Distance_to_University  \
# 0                       214.048651                      4751.978581
# 1                       738.117055                      1511.419338
# 2                       658.291055                      1973.696615
# 3                       530.714935                       863.398657
# 4                      1139.270564                      3067.590359
# ...                            ...                              ...
# 99995                   738.117055                      1511.419338
# 99996                  1224.592962                      1387.869038
# 99997                   418.644973                      2131.457467
# 99998                   971.258388                      3418.712577
# 99999                   500.333954                      2129.036865
#
#        Shortest_Distance_to_School  JS_Price  Region_Name_y  Building_Use_y  \
# 0                       227.236759     34047            강남구             아파트
# 1                       194.500536     85000            양천구             아파트
# 2                        81.579736     63000            구로구             아파트
# 3                       338.546255     36000            양천구             아파트
# 4                       259.515164     49000            양천구             아파트
# ...                            ...       ...            ...             ...
# 99995                   194.500536     30000            송파구             아파트
# 99996                   122.831345    150000            용산구             아파트
# 99997                   130.433463     16000            노원구             아파트
# 99998                    32.848503     36000            마포구             아파트
# 99999                   643.334778     30000            마포구             아파트
#
#       YearMonth   UR  HSP_index
# 0        201801  3.7      103.0
# 1        202110  2.8      188.5
# 2        202106  3.8      177.7
# 3        201301  3.4       72.4
# 4        201712  3.3      100.9
# ...         ...  ...        ...
# 99995    201501  3.7       77.9
# 99996    201907  3.9      122.2
# 99997    201503  4.0       79.4
# 99998    201911  3.1      129.5
# 99999    201206  3.2       75.2
#
# [100000 rows x 22 columns]

# %% [markdown]
# ## Categorical:
#
# - Nominal(variables that have two or more categories, but which do not have an intrinsic order.)
#
#     - Region_Name : 자치구 명
#     - Building_Use : 건물 용도
#
# - Ordinal(variables that have two or more categories just like nominal variables. Only the categories can also be ordered or ranked.)
#
#
# ## Numeric:
#
# - Discrete
#     - YearMonth : 년월
#     - Building_Age : 건물연식
#     - JS_Price : 전세가
#
# - Continous
#     - Sell_Price : 매매 가격
#     - JS_BA = JS_Building Area : 임대 면적
#     - lR = Interest Rate : 금리
#     - UR = Unemployment Rate : 실업률
#     - LC_index = Leading Composite index : 선행종합 지수
#     - CA_index = Comprehensive Accompany index : 동행종합 지수
#     - TC_index = Trailing Composite index : 후행종합 지수
#     - SDT_index = Supply and Demand Trend index = 전세수급동향 지수
#     - HSP_index =
#     - Population : 인구수
#     - Crime_Rates : 범죄율
#     - Shortest_Distance_to_Subway : 가장 가까운 지하철역과의 거리
#     - Shortest_Distance_to_School : 가장 가까운 초중고등학교와의 거리
#     - Shortest_Distance_to_Univ : 가장 가까운 대학교와의 거리
#     - Shortest_Distance_to_Park : 가장 가까운 공원과의 거리

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Floor                            100000 non-null  float64
#  1   Building_Age                     100000 non-null  int64
#  2   JS_BA                            100000 non-null  float64
#  3   Population                       100000 non-null  int64
#  4   IR                               100000 non-null  float64
#  5   LC_index                         100000 non-null  float64
#  6   CA_index                         100000 non-null  float64
#  7   TC_index                         100000 non-null  float64
#  8   SDT_index                        100000 non-null  float64
#  9   Crime_Rates                      100000 non-null  float64
#  10  latitude                         100000 non-null  float64
#  11  longitude                        100000 non-null  float64
#  12  Sell_Price                       100000 non-null  float64
#  13  Shortest_Distance_to_Subway      100000 non-null  float64
#  14  Shortest_Distance_to_University  100000 non-null  float64
#  15  Shortest_Distance_to_School      100000 non-null  float64
#  16  JS_Price                         100000 non-null  int64
#  17  Region_Name_y                    100000 non-null  object
#  18  Building_Use_y                   100000 non-null  object
#  19  YearMonth                        100000 non-null  int64
#  20  UR                               100000 non-null  float64
#  21  HSP_index                        100000 non-null  float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 16.8+ MB

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ### 범주형 변수 인코딩

# %%
def target_encoding(df, target_column):
    # DataFrame의 복사본을 만듭니다.
    df_encoded = df.copy()
    
    for column in df.columns:
        if df[column].dtype == object and column != target_column:
            encoding_map = df.groupby(column)[target_column].mean().to_dict()
            df_encoded[column] = df_encoded[column].map(encoding_map)
    
    return df_encoded

# %%
df_encoded = target_encoding(df, 'JS_Price')

# %% [markdown]
# ### 전체 변수 스케일링

# %%
# StandardScaler 객체 생성
scaler = StandardScaler()

# 정규화할 열 선택 (수치형 데이터만, 원핫인코딩 열 제외)
numeric_columns = df_encoded.select_dtypes(include=['float', 'int']).columns
# numeric_columns = [col for col in numeric_columns if col not in columns_encoded]

# 데이터 정규화 (Z-점수로)
df_encoded[numeric_columns] = scaler.fit_transform(df_encoded[numeric_columns])

# %% [markdown]
# ## Regression Analysis

# %%
df_encoded.columns
# Out:
# Index(['Floor', 'Building_Age', 'JS_BA', 'Population', 'IR', 'LC_index',
#        'CA_index', 'TC_index', 'SDT_index', 'Crime_Rates', 'latitude',
#        'longitude', 'Sell_Price', 'Shortest_Distance_to_Subway',
#        'Shortest_Distance_to_University', 'Shortest_Distance_to_School',
#        'JS_Price', 'Region_Name_y', 'Building_Use_y', 'YearMonth', 'UR',
#        'HSP_index'],
#       dtype='object')

# %%
selected_features = ['LC_index',
 'longitude',
 'JS_BA',
 'TC_index',
 'IR',
 'Population',
 'SDT_index',
 'Building_Age',
 'Building_Use_y',
 'YearMonth',
 'CA_index',
 'Floor',
 'latitude',
 'Shortest_Distance_to_School',
 'Sell_Price',
 'HSP_index',
 'Region_Name_y',
 'Crime_Rates',
 'UR']

# X 데이터 선택
X = df_encoded[selected_features]

# 상수항 추가
X = sm.add_constant(X)

# 종속 변수 선택
Y = df_encoded['JS_Price']

# 회귀 모델 생성
model = sm.OLS(Y, X).fit()

# 결과 요약 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               JS_Price   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     3431.
# Date:                Thu, 05 Oct 2023   Prob (F-statistic):               0.00
# Time:                        17:34:48   Log-Likelihood:            -1.1784e+05
# No. Observations:              100000   AIC:                         2.357e+05
# Df Residuals:                   99981   BIC:                         2.359e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        8.265e-15      0.002   3.32e-12      1.000      -0.005       0.005
# LC_index                        0.3074      0.046      6.731      0.000       0.218       0.397
# longitude                      -0.0006      0.003     -0.235      0.814      -0.006       0.005
# JS_BA                           0.0008      0.003      0.284      0.776      -0.005       0.007
# TC_index                       -0.4263      0.040    -10.568      0.000      -0.505      -0.347
# IR                              0.0128      0.006      2.012      0.044       0.000       0.025
# Population                     -0.0041      0.003     -1.338      0.181      -0.010       0.002
# SDT_index                       0.0230      0.004      5.254      0.000       0.014       0.032
# Building_Age                   -0.0003      0.003     -0.105      0.916      -0.005       0.005
# Building_Use_y              -9.934e-16   1.11e-16     -8.981      0.000   -1.21e-15   -7.77e-16
# YearMonth                       0.2642      0.018     15.009      0.000       0.230       0.299
# CA_index                        0.2147      0.029      7.487      0.000       0.158       0.271
# Floor                           0.0004      0.003      0.155      0.877      -0.005       0.005
# latitude                       -0.0210      0.003     -7.136      0.000      -0.027      -0.015
# Shortest_Distance_to_School     0.0028      0.003      1.105      0.269      -0.002       0.008
# Sell_Price                     -0.0014      0.003     -0.393      0.695      -0.008       0.005
# HSP_index                       0.0486      0.007      6.819      0.000       0.035       0.063
# Region_Name_y                   0.4880      0.002    196.140      0.000       0.483       0.493
# Crime_Rates                    -0.0106      0.003     -3.371      0.001      -0.017      -0.004
# UR                             -0.0311      0.003    -11.072      0.000      -0.037      -0.026
# ==============================================================================
# Omnibus:                    60327.147   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1748373.483
# Skew:                           2.408   Prob(JB):                         0.00
# Kurtosis:                      22.910   Cond. No.                     7.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.02e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## 변수선택법
# - 다중공선성과 회귀계수의 통계적 유의성 고려하여 진행

# %% [markdown]
# ### VIF

# %%
# X 데이터에서 상수항 제거 (VIF 계산에서 상수항은 제외해야 함)
X_without_constant = X.drop('const', axis=1)

# VIF 계산
vif = pd.DataFrame()
vif["Features"] = X_without_constant.columns
vif["VIF"] = [variance_inflation_factor(X_without_constant.values, i) for i in range(X_without_constant.shape[1])]

# %%
vif.sort_values('VIF', ascending = False)
# Out:
#                        Features         VIF
# 0                      LC_index  337.373034
# 3                      TC_index  263.177618
# 10                     CA_index  132.984136
# 9                     YearMonth   50.104664
# 15                    HSP_index    8.207226
# 4                            IR    6.528619
# 6                     SDT_index    3.088687
# 14                   Sell_Price    1.972968
# 17                  Crime_Rates    1.597079
# 5                    Population    1.489820
# 2                         JS_BA    1.431977
# 12                     latitude    1.395205
# 18                           UR    1.277019
# 1                     longitude    1.171397
# 7                  Building_Age    1.105014
# 11                        Floor    1.082818
# 13  Shortest_Distance_to_School    1.042499
# 16                Region_Name_y    1.001400
# 8                Building_Use_y         NaN

# %%
model = pd.DataFrame(model.summary().tables[1])
model
# Out:
#                               0           1          2          3       4  \
# 0                                      coef    std err          t   P>|t|
# 1                         const   8.265e-15      0.002   3.32e-12   1.000
# 2                      LC_index      0.3074      0.046      6.731   0.000
# 3                     longitude     -0.0006      0.003     -0.235   0.814
# 4                         JS_BA      0.0008      0.003      0.284   0.776
# 5                      TC_index     -0.4263      0.040    -10.568   0.000
# 6                            IR      0.0128      0.006      2.012   0.044
# 7                    Population     -0.0041      0.003     -1.338   0.181
# 8                     SDT_index      0.0230      0.004      5.254   0.000
# 9                  Building_Age     -0.0003      0.003     -0.105   0.916
# 10               Building_Use_y  -9.934e-16   1.11e-16     -8.981   0.000
# 11                    YearMonth      0.2642      0.018     15.009   0.000
# 12                     CA_index      0.2147      0.029      7.487   0.000
# 13                        Floor      0.0004      0.003      0.155   0.877
# 14                     latitude     -0.0210      0.003     -7.136   0.000
# 15  Shortest_Distance_to_School      0.0028      0.003      1.105   0.269
# 16                   Sell_Price     -0.0014      0.003     -0.393   0.695
# 17                    HSP_index      0.0486      0.007      6.819   0.000
# 18                Region_Name_y      0.4880      0.002    196.140   0.000
# 19                  Crime_Rates     -0.0106      0.003     -3.371   0.001
# 20                           UR     -0.0311      0.003    -11.072   0.000
#
#             5          6
# 0      [0.025     0.975]
# 1      -0.005      0.005
# 2       0.218      0.397
# 3      -0.006      0.005
# 4      -0.005      0.007
# 5      -0.505     -0.347
# 6       0.000      0.025
# 7      -0.010      0.002
# 8       0.014      0.032
# 9      -0.005      0.005
# 10  -1.21e-15  -7.77e-16
# 11      0.230      0.299
# 12      0.158      0.271
# 13     -0.005      0.005
# 14     -0.027     -0.015
# 15     -0.002      0.008
# 16     -0.008      0.005
# 17      0.035      0.063
# 18      0.483      0.493
# 19     -0.017     -0.004
# 20     -0.037     -0.026

# %%
delete_columns = []
for i in range(2, len(model.index)):
    if vif['VIF'].iloc[i-2] > 5:
        delete_columns.append(model.iloc[i, 0].data)
delete_columns
# Out:
# ['LC_index', 'TC_index', 'IR', 'YearMonth', 'CA_index', 'HSP_index']

# %%
selected_features = list(set(selected_features) - set(delete_columns))
selected_features
# Out:
# ['Sell_Price',
#  'UR',
#  'Population',
#  'Floor',
#  'JS_BA',
#  'SDT_index',
#  'Building_Use_y',
#  'Region_Name_y',
#  'latitude',
#  'Shortest_Distance_to_School',
#  'Building_Age',
#  'Crime_Rates',
#  'longitude']

# %% [markdown]
# ### 회귀계수의 P-VALUE

# %%
# X 데이터 선택
X = df_encoded[selected_features]

# 상수항 추가
X = sm.add_constant(X)

# 종속 변수 선택
Y = df_encoded['JS_Price']

# 회귀 모델 생성
model = sm.OLS(Y, X).fit()

# 결과 요약 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               JS_Price   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     3323.
# Date:                Thu, 05 Oct 2023   Prob (F-statistic):               0.00
# Time:                        17:34:52   Log-Likelihood:            -1.2511e+05
# No. Observations:              100000   AIC:                         2.503e+05
# Df Residuals:                   99987   BIC:                         2.504e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        -2.35e-15      0.003  -8.79e-13      1.000      -0.005       0.005
# Sell_Price                      0.2010      0.003     62.237      0.000       0.195       0.207
# UR                              0.0202      0.003      7.413      0.000       0.015       0.026
# Population                     -0.0829      0.003    -26.167      0.000      -0.089      -0.077
# Floor                           0.0023      0.003      0.813      0.416      -0.003       0.008
# JS_BA                          -0.1220      0.003    -40.982      0.000      -0.128      -0.116
# SDT_index                      -0.0776      0.003    -27.900      0.000      -0.083      -0.072
# Building_Use_y               -1.05e-16   1.12e-18    -93.719      0.000   -1.07e-16   -1.03e-16
# Region_Name_y                   0.4819      0.003    180.177      0.000       0.477       0.487
# latitude                        0.0016      0.003      0.501      0.617      -0.005       0.008
# Shortest_Distance_to_School     0.0210      0.003      7.718      0.000       0.016       0.026
# Building_Age                    0.0201      0.003      7.186      0.000       0.015       0.026
# Crime_Rates                    -0.1002      0.003    -31.266      0.000      -0.107      -0.094
# longitude                      -0.0280      0.003     -9.694      0.000      -0.034      -0.022
# ==============================================================================
# Omnibus:                    57928.939   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1323456.642
# Skew:                           2.349   Prob(JB):                         0.00
# Kurtosis:                      20.192   Cond. No.                     1.82e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.22e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model = pd.DataFrame(model.summary().tables[1])
model
# Out:
#                               0           1          2          3       4  \
# 0                                      coef    std err          t   P>|t|
# 1                         const   -2.35e-15      0.003  -8.79e-13   1.000
# 2                    Sell_Price      0.2010      0.003     62.237   0.000
# 3                            UR      0.0202      0.003      7.413   0.000
# 4                    Population     -0.0829      0.003    -26.167   0.000
# 5                         Floor      0.0023      0.003      0.813   0.416
# 6                         JS_BA     -0.1220      0.003    -40.982   0.000
# 7                     SDT_index     -0.0776      0.003    -27.900   0.000
# 8                Building_Use_y   -1.05e-16   1.12e-18    -93.719   0.000
# 9                 Region_Name_y      0.4819      0.003    180.177   0.000
# 10                     latitude      0.0016      0.003      0.501   0.617
# 11  Shortest_Distance_to_School      0.0210      0.003      7.718   0.000
# 12                 Building_Age      0.0201      0.003      7.186   0.000
# 13                  Crime_Rates     -0.1002      0.003    -31.266   0.000
# 14                    longitude     -0.0280      0.003     -9.694   0.000
#
#             5          6
# 0      [0.025     0.975]
# 1      -0.005      0.005
# 2       0.195      0.207
# 3       0.015      0.026
# 4      -0.089     -0.077
# 5      -0.003      0.008
# 6      -0.128     -0.116
# 7      -0.083     -0.072
# 8   -1.07e-16  -1.03e-16
# 9       0.477      0.487
# 10     -0.005      0.008
# 11      0.016      0.026
# 12      0.015      0.026
# 13     -0.107     -0.094
# 14     -0.034     -0.022

# %%
delete_columns = []
for i in range(2, len(model.index)):
    if float(model.iloc[i, 4].data) > 0.01:
        delete_columns.append(model.iloc[i, 0].data)
delete_columns
# Out:
# ['Floor', 'latitude']

# %%
selected_features = list(set(selected_features) - set(delete_columns))
selected_features
# Out:
# ['Sell_Price',
#  'UR',
#  'Population',
#  'JS_BA',
#  'SDT_index',
#  'Building_Use_y',
#  'Region_Name_y',
#  'Shortest_Distance_to_School',
#  'Building_Age',
#  'Crime_Rates',
#  'longitude']

# %%
# X 데이터 선택
X = df_encoded[selected_features]

# 상수항 추가
X = sm.add_constant(X)

# 종속 변수 선택
Y = df_encoded['JS_Price']

# 회귀 모델 생성
model = sm.OLS(Y, X).fit()

# 결과 요약 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               JS_Price   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     3987.
# Date:                Thu, 05 Oct 2023   Prob (F-statistic):               0.00
# Time:                        17:34:52   Log-Likelihood:            -1.2511e+05
# No. Observations:              100000   AIC:                         2.503e+05
# Df Residuals:                   99989   BIC:                         2.504e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -2.498e-15      0.003  -9.34e-13      1.000      -0.005       0.005
# Sell_Price                      0.2007      0.003     65.692      0.000       0.195       0.207
# UR                              0.0202      0.003      7.412      0.000       0.015       0.026
# Population                     -0.0834      0.003    -27.342      0.000      -0.089      -0.077
# JS_BA                          -0.1218      0.003    -41.079      0.000      -0.128      -0.116
# SDT_index                      -0.0777      0.003    -27.942      0.000      -0.083      -0.072
# Building_Use_y               2.851e-16   1.72e-18    165.861      0.000    2.82e-16    2.88e-16
# Region_Name_y                   0.4819      0.003    180.187      0.000       0.477       0.487
# Shortest_Distance_to_School     0.0208      0.003      7.694      0.000       0.015       0.026
# Building_Age                    0.0197      0.003      7.231      0.000       0.014       0.025
# Crime_Rates                    -0.1008      0.003    -33.756      0.000      -0.107      -0.095
# longitude                      -0.0275      0.003     -9.878      0.000      -0.033      -0.022
# ==============================================================================
# Omnibus:                    57931.250   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1323543.957
# Skew:                           2.350   Prob(JB):                         0.00
# Kurtosis:                      20.192   Cond. No.                     3.71e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.17e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# - 모든 변수가 통계적으로 유의한 것을 확인할 수 있다.

# %% [markdown]
# ## 모델가정 확인

# %% [markdown]
# ### 선형성
# - 선형성은 계수의 유의성 검정과 다중공선성을 고려하여 변수를 걸러냄으로써 어느 정도 만족하는 것으로 보인다.

# %%
fitted = model.predict(X)
residual = df_encoded['JS_Price'] - fitted

sns.regplot(x=fitted, y=residual, lowess=True, line_kws={'color':'red'})

plt.plot([fitted.min(), fitted.max()], [0, 0], '--', color='grey')

# %% [markdown]
# ### 정규성

# %%
fitted = model.predict(X)
residual = df_encoded['JS_Price'] - fitted
sr = scipy.stats.zscore(residual)
(x, y), _ = scipy.stats.probplot(sr)

# Scatterplot 그리기
sns.scatterplot(x=x, y=y)
plt.plot([-3, 3], [-3, 3], '--', color='grey')

# Shapiro-Wilk 정규성 검정
scipy.stats.shapiro(residual)
# Out:
# ShapiroResult(statistic=0.8658426403999329, pvalue=0.0)

# %% [markdown]
# ### 등분산성

# %%
sns.regplot(x=fitted, y=np.sqrt(np.abs(sr)), lowess=True, line_kws={'color': 'red'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 독립성

# %%
print(model.summary().tables[2])
# Out:
# ==============================================================================
# Omnibus:                    57931.250   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1323543.957
# Skew:                           2.350   Prob(JB):                         0.00
# Kurtosis:                      20.192   Cond. No.                     3.71e+16
# ==============================================================================

# %% [markdown]
# - Durbin-Watson:2.002로 1.5~2.5사이이므로 잔차 간의 자기상관이 없다고 할 수 있으며, 회귀 모델은 독립성 가정을 만족

# %% [markdown]
# ## 최종 모델 점검

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               JS_Price   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     3987.
# Date:                Thu, 05 Oct 2023   Prob (F-statistic):               0.00
# Time:                        18:12:11   Log-Likelihood:            -1.2511e+05
# No. Observations:              100000   AIC:                         2.503e+05
# Df Residuals:                   99989   BIC:                         2.504e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -2.498e-15      0.003  -9.34e-13      1.000      -0.005       0.005
# Sell_Price                      0.2007      0.003     65.692      0.000       0.195       0.207
# UR                              0.0202      0.003      7.412      0.000       0.015       0.026
# Population                     -0.0834      0.003    -27.342      0.000      -0.089      -0.077
# JS_BA                          -0.1218      0.003    -41.079      0.000      -0.128      -0.116
# SDT_index                      -0.0777      0.003    -27.942      0.000      -0.083      -0.072
# Building_Use_y               2.851e-16   1.72e-18    165.861      0.000    2.82e-16    2.88e-16
# Region_Name_y                   0.4819      0.003    180.187      0.000       0.477       0.487
# Shortest_Distance_to_School     0.0208      0.003      7.694      0.000       0.015       0.026
# Building_Age                    0.0197      0.003      7.231      0.000       0.014       0.025
# Crime_Rates                    -0.1008      0.003    -33.756      0.000      -0.107      -0.095
# longitude                      -0.0275      0.003     -9.878      0.000      -0.033      -0.022
# ==============================================================================
# Omnibus:                    57931.250   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1323543.957
# Skew:                           2.350   Prob(JB):                         0.00
# Kurtosis:                      20.192   Cond. No.                     3.71e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.17e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model.params.sort_values(ascending=False)
# Out:
# Region_Name_y                  4.819304e-01
# Sell_Price                     2.007387e-01
# Shortest_Distance_to_School    2.075696e-02
# UR                             2.017524e-02
# Building_Age                   1.972773e-02
# Building_Use_y                 2.851183e-16
# const                         -2.498408e-15
# longitude                     -2.747507e-02
# SDT_index                     -7.768185e-02
# Population                    -8.340808e-02
# Crime_Rates                   -1.007887e-01
# JS_BA                         -1.218065e-01
# dtype: float64
